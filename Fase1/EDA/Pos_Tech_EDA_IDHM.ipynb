# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoShoiti/pos-tech-ai-scientist/blob/main/Fase1/EDA/Pos_Tech_EDA_IDHM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
idhm = pd.read_excel('IDH_2010.xls')

# %%
idhm.head()
# Out:
#     ANO  Código da Unidade da Federação Nome da Unidade da Federação  \
# 0  2010                              11                     Rondônia
# 1  2010                              11                     Rondônia
# 2  2010                              11                     Rondônia
# 3  2010                              11                     Rondônia
# 4  2010                              11                     Rondônia
#
#    Código do Município              Município  Esperança de vida ao nascer  \
# 0               110001  ALTA FLORESTA D'OESTE                        70.75
# 1               110002              ARIQUEMES                        73.36
# 2               110003                 CABIXI                        70.39
# 3               110004                 CACOAL                        74.27
# 4               110005             CEREJEIRAS                        72.94
#
#    Taxa de fecundidade total  Mortalidade infantil  \
# 0                       2.24                  23.8
# 1                       1.91                  19.2
# 2                       2.15                  24.8
# 3                       1.90                  14.3
# 4                       2.12                  18.1
#
#    Mortalidade até 5 anos de idade  Razão de dependência  ...  \
# 0                            25.49                 47.37  ...
# 1                            20.53                 46.68  ...
# 2                            26.58                 48.12  ...
# 3                            15.38                 43.79  ...
# 4                            19.42                 45.67  ...
#
#    População de 15 a 17 anos.1  População de 18 anos ou mais.1  \
# 0                         1602                           16431
# 1                         5256                           60213
# 2                          381                            4306
# 3                         4547                           54356
# 4                         1033                           11786
#
#    População total em domicílios particulares permanentes  \
# 0                                              24097
# 1                                              89766
# 2                                               6303
# 3                                              78141
# 4                                              16942
#
#    População total em domicílios particulares permanentes, exceto com renda nula  \
# 0                                              22429
# 1                                              88730
# 2                                               6156
# 3                                              76876
# 4                                              16815
#
#    Subíndice de escolaridade - IDHM Educação  \
# 0                                      0.368
# 1                                      0.514
# 2                                      0.357
# 3                                      0.488
# 4                                      0.430
#
#    Subíndice de frequência escolar - IDHM Educação   IDHM  IDHM Educação  \
# 0                                            0.629  0.641          0.526
# 1                                            0.648  0.702          0.600
# 2                                            0.700  0.650          0.559
# 3                                            0.698  0.718          0.620
# 4                                            0.712  0.692          0.602
#
#    IDHM Longevidade  IDHM Renda
# 0             0.763       0.657
# 1             0.806       0.716
# 2             0.757       0.650
# 3             0.821       0.727
# 4             0.799       0.688
#
# [5 rows x 237 columns]

# %% [markdown]
# ### Tamanho da Base de Dados

# %%
idhm.shape
# Out:
# (5564, 237)

# %%
idhm.dtypes
# Out:
# ANO                                                  int64
# Código da Unidade da Federação                       int64
# Nome da Unidade da Federação                        object
# Código do Município                                  int64
# Município                                           object
#                                                     ...
# Subíndice de frequência escolar - IDHM Educação    float64
# IDHM                                               float64
# IDHM Educação                                      float64
# IDHM Longevidade                                   float64
# IDHM Renda                                         float64
# Length: 237, dtype: object

# %%
idhm.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
idhm.columns
# Out:
# Index(['ANO', 'Código da Unidade da Federação', 'Nome da Unidade da Federação',
#        'Código do Município', 'Município', 'Esperança de vida ao nascer',
#        'Taxa de fecundidade total', 'Mortalidade infantil',
#        'Mortalidade até 5 anos de idade', 'Razão de dependência',
#        ...
#        'População de 15 a 17 anos.1', 'População de 18 anos ou mais.1',
#        'População total em domicílios particulares permanentes',
#        'População total em domicílios particulares permanentes, exceto com renda nula',
#        'Subíndice de escolaridade - IDHM Educação',
#        'Subíndice de frequência escolar - IDHM Educação', 'IDHM',
#        'IDHM Educação', 'IDHM Longevidade', 'IDHM Renda'],
#       dtype='object', length=237)

# %%
df_idhm = idhm[['Nome da Unidade da Federação', 'Município', 'IDHM', 'IDHM Educação', 'IDHM Longevidade', 'IDHM Renda']]
df_idhm
# Out:
#      Nome da Unidade da Federação              Município   IDHM  \
# 0                        Rondônia  ALTA FLORESTA D'OESTE  0.641
# 1                        Rondônia              ARIQUEMES  0.702
# 2                        Rondônia                 CABIXI  0.650
# 3                        Rondônia                 CACOAL  0.718
# 4                        Rondônia             CEREJEIRAS  0.692
# ...                           ...                    ...    ...
# 5559                        Goiás             VIANÓPOLIS  0.712
# 5560                        Goiás         VICENTINÓPOLIS  0.684
# 5561                        Goiás               VILA BOA  0.647
# 5562                        Goiás          VILA PROPÍCIO  0.634
# 5563             Distrito Federal               BRASÍLIA  0.824
#
#       IDHM Educação  IDHM Longevidade  IDHM Renda
# 0             0.526             0.763       0.657
# 1             0.600             0.806       0.716
# 2             0.559             0.757       0.650
# 3             0.620             0.821       0.727
# 4             0.602             0.799       0.688
# ...             ...               ...         ...
# 5559          0.622             0.818       0.710
# 5560          0.562             0.804       0.707
# 5561          0.534             0.818       0.619
# 5562          0.505             0.802       0.629
# 5563          0.742             0.873       0.863
#
# [5564 rows x 6 columns]

# %%
df_idhm.columns = ['uf', 'municipio', 'idhm', 'idhm_educacao', 'idhm_longevidade', 'idhm_renda']

# %%
df_idhm.head()
# Out:
#          uf              municipio   idhm  idhm_educacao  idhm_longevidade  \
# 0  Rondônia  ALTA FLORESTA D'OESTE  0.641          0.526             0.763
# 1  Rondônia              ARIQUEMES  0.702          0.600             0.806
# 2  Rondônia                 CABIXI  0.650          0.559             0.757
# 3  Rondônia                 CACOAL  0.718          0.620             0.821
# 4  Rondônia             CEREJEIRAS  0.692          0.602             0.799
#
#    idhm_renda
# 0       0.657
# 1       0.716
# 2       0.650
# 3       0.727
# 4       0.688

# %%
df_idhm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5564 entries, 0 to 5563
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uf                5564 non-null   object
#  1   municipio         5564 non-null   object
#  2   idhm              5564 non-null   float64
#  3   idhm_educacao     5564 non-null   float64
#  4   idhm_longevidade  5564 non-null   float64
#  5   idhm_renda        5564 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 260.9+ KB

# %%
df_idhm.nunique()
# Out:
# uf                    27
# municipio           5329
# idhm                 349
# idhm_educacao        466
# idhm_longevidade     220
# idhm_renda           390
# dtype: int64

# %% [markdown]
# Estatística Descritiva

# %%
df_idhm.describe().round(2)
# Out:
#           idhm  idhm_educacao  idhm_longevidade  idhm_renda
# count  5564.00        5564.00           5564.00     5564.00
# mean      0.66           0.56              0.80        0.64
# std       0.07           0.09              0.04        0.08
# min       0.42           0.21              0.67        0.40
# 25%       0.60           0.49              0.77        0.57
# 50%       0.66           0.56              0.81        0.65
# 75%       0.72           0.63              0.84        0.71
# max       0.86           0.82              0.89        0.89

# %% [markdown]
# Classificação IDHM
#
# 0 - 0,499 - Baixo Desenvolvimento Humano
#
# 0,5 - 0,799 - Médio Desenvolvimento Humano
#
# 0,8 - 1 - Alto Desenvolvimento Humano

# %%
df_idhm["idhm"]
# Out:
# 0       0.641
# 1       0.702
# 2       0.650
# 3       0.718
# 4       0.692
#         ...
# 5559    0.712
# 5560    0.684
# 5561    0.647
# 5562    0.634
# 5563    0.824
# Name: idhm, Length: 5564, dtype: float64

# %%
def idhm_class(df):
  if df["idhm"] <= 0.499:
    return "Baixo Desenvolvimento Humano"
  elif df["idhm"] >= 0.8:
    return "Alto Desenvolvimento Humano"
  else:
    return "Médio Desenvolvimento Humano"

# %%
df_idhm['classe'] = df_idhm.apply(idhm_class, axis=1)
df_idhm
# Out:
#                     uf              municipio   idhm  idhm_educacao  \
# 0             Rondônia  ALTA FLORESTA D'OESTE  0.641          0.526
# 1             Rondônia              ARIQUEMES  0.702          0.600
# 2             Rondônia                 CABIXI  0.650          0.559
# 3             Rondônia                 CACOAL  0.718          0.620
# 4             Rondônia             CEREJEIRAS  0.692          0.602
# ...                ...                    ...    ...            ...
# 5559             Goiás             VIANÓPOLIS  0.712          0.622
# 5560             Goiás         VICENTINÓPOLIS  0.684          0.562
# 5561             Goiás               VILA BOA  0.647          0.534
# 5562             Goiás          VILA PROPÍCIO  0.634          0.505
# 5563  Distrito Federal               BRASÍLIA  0.824          0.742
#
#       idhm_longevidade  idhm_renda                        classe
# 0                0.763       0.657  Médio Desenvolvimento Humano
# 1                0.806       0.716  Médio Desenvolvimento Humano
# 2                0.757       0.650  Médio Desenvolvimento Humano
# 3                0.821       0.727  Médio Desenvolvimento Humano
# 4                0.799       0.688  Médio Desenvolvimento Humano
# ...                ...         ...                           ...
# 5559             0.818       0.710  Médio Desenvolvimento Humano
# 5560             0.804       0.707  Médio Desenvolvimento Humano
# 5561             0.818       0.619  Médio Desenvolvimento Humano
# 5562             0.802       0.629  Médio Desenvolvimento Humano
# 5563             0.873       0.863   Alto Desenvolvimento Humano
#
# [5564 rows x 7 columns]

# %%
df_idhm['classe'].value_counts()
# Out:
# classe
# Médio Desenvolvimento Humano    5488
# Alto Desenvolvimento Humano       44
# Baixo Desenvolvimento Humano      32
# Name: count, dtype: int64

# %%
sns.pairplot(df_idhm, hue='classe')

# %%
df_idhm_estado = pd.DataFrame(df_idhm.groupby('uf')['idhm'].mean().round(2)).reset_index()

# %%
df_idhm_estado
# Out:
#                      uf  idhm
# 0                  Acre  0.59
# 1               Alagoas  0.56
# 2                 Amapá  0.64
# 3              Amazonas  0.57
# 4                 Bahia  0.59
# 5                 Ceará  0.62
# 6      Distrito Federal  0.82
# 7        Espírito Santo  0.69
# 8                 Goiás  0.69
# 9              Maranhão  0.58
# 10          Mato Grosso  0.68
# 11   Mato Grosso do Sul  0.68
# 12         Minas Gerais  0.67
# 13               Paraná  0.70
# 14              Paraíba  0.59
# 15                 Pará  0.58
# 16           Pernambuco  0.60
# 17                Piauí  0.57
# 18  Rio Grande do Norte  0.61
# 19    Rio Grande do Sul  0.71
# 20       Rio de Janeiro  0.71
# 21             Rondônia  0.64
# 22              Roraima  0.61
# 23       Santa Catarina  0.73
# 24              Sergipe  0.60
# 25            São Paulo  0.74
# 26            Tocantins  0.64

# %%
df_idhm_estado['classe'] = df_idhm_estado.apply(idhm_class, axis=1)
df_idhm_estado
# Out:
#                      uf  idhm                        classe
# 0                  Acre  0.59  Médio Desenvolvimento Humano
# 1               Alagoas  0.56  Médio Desenvolvimento Humano
# 2                 Amapá  0.64  Médio Desenvolvimento Humano
# 3              Amazonas  0.57  Médio Desenvolvimento Humano
# 4                 Bahia  0.59  Médio Desenvolvimento Humano
# 5                 Ceará  0.62  Médio Desenvolvimento Humano
# 6      Distrito Federal  0.82   Alto Desenvolvimento Humano
# 7        Espírito Santo  0.69  Médio Desenvolvimento Humano
# 8                 Goiás  0.69  Médio Desenvolvimento Humano
# 9              Maranhão  0.58  Médio Desenvolvimento Humano
# 10          Mato Grosso  0.68  Médio Desenvolvimento Humano
# 11   Mato Grosso do Sul  0.68  Médio Desenvolvimento Humano
# 12         Minas Gerais  0.67  Médio Desenvolvimento Humano
# 13               Paraná  0.70  Médio Desenvolvimento Humano
# 14              Paraíba  0.59  Médio Desenvolvimento Humano
# 15                 Pará  0.58  Médio Desenvolvimento Humano
# 16           Pernambuco  0.60  Médio Desenvolvimento Humano
# 17                Piauí  0.57  Médio Desenvolvimento Humano
# 18  Rio Grande do Norte  0.61  Médio Desenvolvimento Humano
# 19    Rio Grande do Sul  0.71  Médio Desenvolvimento Humano
# 20       Rio de Janeiro  0.71  Médio Desenvolvimento Humano
# 21             Rondônia  0.64  Médio Desenvolvimento Humano
# 22              Roraima  0.61  Médio Desenvolvimento Humano
# 23       Santa Catarina  0.73  Médio Desenvolvimento Humano
# 24              Sergipe  0.60  Médio Desenvolvimento Humano
# 25            São Paulo  0.74  Médio Desenvolvimento Humano
# 26            Tocantins  0.64  Médio Desenvolvimento Humano

# %%
df_idhm_estado['classe'].value_counts()
# Out:
# classe
# Médio Desenvolvimento Humano    26
# Alto Desenvolvimento Humano      1
# Name: count, dtype: int64

# %%
df_idhm_estado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   uf      27 non-null     object
#  1   idhm    27 non-null     float64
#  2   classe  27 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 780.0+ bytes

# %%
df_idhm_estado.describe().round(2)
# Out:
#         idhm
# count  27.00
# mean    0.64
# std     0.06
# min     0.56
# 25%     0.59
# 50%     0.64
# 75%     0.69
# max     0.82

# %%
sns.boxplot(y=df_idhm_estado['idhm'], data=df_idhm_estado)

plt.title('Boxplot dos valores por classificação')
plt.xlabel("IDHM")
plt.ylabel("Valores")
plt.show()

# %%
#Tamanho da Figura
plt.figure(figsize=(12,6))

#Paleta de Cores
Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

#Plotagem
plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm'],
        width=0.9,
        color = Paleta_Cores
        )

#Titulo
plt.title('UF x IDHM', loc = 'left', fontsize = 18)

#Labels
plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH com a média dos Estados', fontsize = 14)
plt.xticks(rotation = 90);

# %%
df_idhm_estado = df_idhm_estado.sort_values(by="idhm", ascending=False)

plt.figure(figsize=(12,6))

Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm'],
        width=0.9,
        color = Paleta_Cores
        )

plt.title('UF x IDHM', loc = 'left', fontsize = 18)

plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH com a média dos Estados', fontsize = 14)
plt.xticks(rotation = 90);

# %%
# Criar um gráfico de barras usando o Plotly
fig = px.bar(df_idhm_estado, x='uf', y='idhm', text='idhm', color = 'classe', color_discrete_sequence=['orange','green'])


# Adicionar título e rótulos dos eixos
fig.update_layout(title='Gráfico de Barras',
                  xaxis_title='UF',
                  yaxis_title='idhm')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9ea3b6ac-45ff-4dcd-81a2-0ee057b4e18d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ea3b6ac-45ff-4dcd-81a2-0ee057b4e18d")) {                    Plotly.newPlot(                        "9ea3b6ac-45ff-4dcd-81a2-0ee057b4e18d",                        [{"alignmentgroup":"True","hovertemplate":"classe=Alto Desenvolvimento Humano\u003cbr\u003euf=%{x}\u003cbr\u003eidhm=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alto Desenvolvimento Humano","marker":{"color":"orange","pattern":{"shape":""}},"name":"Alto Desenvolvimento Humano","offsetgroup":"Alto Desenvolvimento Humano","orientation":"v","showlegend":true,"text":[0.82],"textposition":"auto","x":["Distrito Federal"],"xaxis":"x","y":[0.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"classe=Médio Desenvolvimento Humano\u003cbr\u003euf=%{x}\u003cbr\u003eidhm=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Médio Desenvolvimento Humano","marker":{"color":"green","pattern":{"shape":""}},"name":"Médio Desenvolvimento Humano","offsetgroup":"Médio Desenvolvimento Humano","orientation":"v","showlegend":true,"text":[0.74,0.73,0.71,0.71,0.7,0.69,0.69,0.68,0.68,0.67,0.64,0.64,0.64,0.62,0.61,0.61,0.6,0.6,0.59,0.59,0.59,0.58,0.58,0.57,0.57,0.56],"textposition":"auto","x":["São Paulo","Santa Catarina","Rio Grande do Sul","Rio de Janeiro","Paraná","Espírito Santo","Goiás","Mato Grosso","Mato Grosso do Sul","Minas Gerais","Rondônia","Tocantins","Amapá","Ceará","Roraima","Rio Grande do Norte","Sergipe","Pernambuco","Acre","Paraíba","Bahia","Maranhão","Pará","Amazonas","Piauí","Alagoas"],"xaxis":"x","y":[0.74,0.73,0.71,0.71,0.7,0.69,0.69,0.68,0.68,0.67,0.64,0.64,0.64,0.62,0.61,0.61,0.6,0.6,0.59,0.59,0.59,0.58,0.58,0.57,0.57,0.56],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444 ...

# %%
fig = px.treemap(df_idhm_estado, path=['uf'], values='idhm', title='TreeMap')

fig.update_traces(root_color="lightgrey")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b68bd461-e9ed-44dc-b39d-b0551f2220d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b68bd461-e9ed-44dc-b39d-b0551f2220d6")) {                    Plotly.newPlot(                        "b68bd461-e9ed-44dc-b39d-b0551f2220d6",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eidhm=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Acre","Alagoas","Amapá","Amazonas","Bahia","Ceará","Distrito Federal","Espírito Santo","Goiás","Maranhão","Mato Grosso","Mato Grosso do Sul","Minas Gerais","Paraná","Paraíba","Pará","Pernambuco","Piauí","Rio Grande do Norte","Rio Grande do Sul","Rio de Janeiro","Rondônia","Roraima","Santa Catarina","Sergipe","São Paulo","Tocantins"],"labels":["Acre","Alagoas","Amapá","Amazonas","Bahia","Ceará","Distrito Federal","Espírito Santo","Goiás","Maranhão","Mato Grosso","Mato Grosso do Sul","Minas Gerais","Paraná","Paraíba","Pará","Pernambuco","Piauí","Rio Grande do Norte","Rio Grande do Sul","Rio de Janeiro","Rondônia","Roraima","Santa Catarina","Sergipe","São Paulo","Tocantins"],"name":"","parents":["","","","","","","","","","","","","","","","","","","","","","","","","","",""],"values":[0.59,0.56,0.64,0.57,0.59,0.62,0.82,0.69,0.69,0.58,0.68,0.68,0.67,0.7,0.59,0.58,0.6,0.57,0.61,0.71,0.71,0.64,0.61,0.73,0.6,0.74,0.64],"type":"treemap","root":{"color":"lightgrey"}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"] ...

# %%
df_idhm_estado = pd.DataFrame(df_idhm.groupby('uf')[['idhm','idhm_educacao', 'idhm_longevidade','idhm_renda']].mean().round(2)).reset_index()

# %%
sns.pairplot(df_idhm, hue = 'classe')

# %%
cols_corr = [c for c in ["idhm_educacao", "idhm_renda", "idhm_longevidade"] if c in df_idhm.columns]
corr = df_idhm[cols_corr].corr()

sns.heatmap(corr, annot=True, fmt=".2f", cmap="rocket", vmin=-1, vmax=1)
plt.title("Matriz de correlação – IDHM e dimensões")
plt.tight_layout()
plt.show()

# %%
df_idhm_estado.describe()
# Out:
#             idhm  idhm_educacao  idhm_longevidade  idhm_renda
# count  27.000000      27.000000         27.000000   27.000000
# mean    0.644815       0.542222          0.793333    0.630741
# std     0.064651       0.076678          0.037107    0.078296
# min     0.560000       0.440000          0.740000    0.530000
# 25%     0.590000       0.485000          0.760000    0.570000
# 50%     0.640000       0.550000          0.790000    0.610000
# 75%     0.690000       0.595000          0.820000    0.685000
# max     0.820000       0.740000          0.870000    0.860000

# %%
plt.figure(figsize=(12,6))

Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm_educacao'],
        width=0.9,
        color = Paleta_Cores
        )

plt.title('UF x IDHM Educação', loc = 'left', fontsize = 18)

plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH', fontsize = 14)
plt.xticks(rotation = 90);

# %%
plt.figure(figsize=(12,6))

Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm_longevidade'],
        width=0.9,
        color = Paleta_Cores
        )

plt.title('UF x IDHM Longevidade', loc = 'left', fontsize = 18)

plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH', fontsize = 14)
plt.xticks(rotation = 90);

# %%
plt.figure(figsize=(12,6))

Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm_renda'],
        width=0.9,
        color = Paleta_Cores
        )

plt.title('UF x IDHM Renda', loc = 'left', fontsize = 18)

plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH', fontsize = 14)
plt.xticks(rotation = 90);

# %%
plt.figure()
sns.boxplot(data=df_idhm, x="uf", y="idhm") #municipio
plt.title("Distribuição do IDHM por Estado")
plt.xlabel("Região")
plt.ylabel("IDHM")
plt.tight_layout()
plt.xticks(rotation = 90);
plt.show()

# %%
mapa_regiao_nome = {
    "Acre": "Norte",
    "Amapá": "Norte",
    "Amazonas": "Norte",
    "Pará": "Norte",
    "Rondônia": "Norte",
    "Roraima": "Norte",
    "Tocantins": "Norte",

    "Alagoas": "Nordeste",
    "Bahia": "Nordeste",
    "Ceará": "Nordeste",
    "Maranhão": "Nordeste",
    "Paraíba": "Nordeste",
    "Pernambuco": "Nordeste",
    "Piauí": "Nordeste",
    "Rio Grande do Norte": "Nordeste",
    "Sergipe": "Nordeste",

    "Distrito Federal": "Centro-Oeste",
    "Goiás": "Centro-Oeste",
    "Mato Grosso": "Centro-Oeste",
    "Mato Grosso do Sul": "Centro-Oeste",

    "Espírito Santo": "Sudeste",
    "Minas Gerais": "Sudeste",
    "Rio de Janeiro": "Sudeste",
    "São Paulo": "Sudeste",

    "Paraná": "Sul",
    "Rio Grande do Sul": "Sul",
    "Santa Catarina": "Sul",
}

df_idhm["regiao"] = df_idhm["uf"].map(mapa_regiao_nome)

df_idhm[["uf", "regiao"]].drop_duplicates().sort_values("regiao")
# Out:
#                        uf        regiao
# 5563     Distrito Federal  Centro-Oeste
# 5176          Mato Grosso  Centro-Oeste
# 5098   Mato Grosso do Sul  Centro-Oeste
# 5317                Goiás  Centro-Oeste
# 1825                Bahia      Nordeste
# 1750              Sergipe      Nordeste
# 1463           Pernambuco      Nordeste
# 1240              Paraíba      Nordeste
# 1073  Rio Grande do Norte      Nordeste
# 1648              Alagoas      Nordeste
# 666                 Piauí      Nordeste
# 449              Maranhão      Nordeste
# 889                 Ceará      Nordeste
# 52                   Acre         Norte
# 74               Amazonas         Norte
# 0                Rondônia         Norte
# 151                  Pará         Norte
# 294                 Amapá         Norte
# 310             Tocantins         Norte
# 136               Roraima         Norte
# 2242         Minas Gerais       Sudeste
# 3095       Espírito Santo       Sudeste
# 3265            São Paulo       Sudeste
# 3173       Rio de Janeiro       Sudeste
# 3910               Paraná           Sul
# 4309       Santa Catarina           Sul
# 4602    Rio Grande do Sul           Sul

# %%
idhm_regiao = df_idhm.groupby("regiao")["idhm"].mean().sort_values()
idhm_regiao
# Out:
# regiao
# Nordeste        0.590672
# Norte           0.607951
# Centro-Oeste    0.689468
# Sudeste         0.698984
# Sul             0.714113
# Name: idhm, dtype: float64

# %%
plt.figure()
sns.barplot(x=idhm_regiao.index, y=idhm_regiao.values)
plt.title("IDHM médio por região")
plt.xlabel("Região")
plt.ylabel("IDHM médio")
plt.tight_layout()
plt.show()

# %%
plt.figure()
sns.boxplot(data=df_idhm, x="regiao", y="idhm") #municipio
plt.title("Distribuição do IDHM por região")
plt.xlabel("Região")
plt.ylabel("IDHM")
plt.tight_layout()
plt.show()

# %%
N = 10

if "municipio" in df_idhm.columns:
    maiores = df_idhm.sort_values("idhm", ascending=False).head(N)[["municipio", "uf", "idhm","regiao"]].copy()
    menores = df_idhm.sort_values("idhm", ascending=True).head(N)[["municipio", "uf", "idhm","regiao"]].copy()
else:
    maiores = df_idhm.sort_values("idhm", ascending=False).head(N)[["uf", "idhm"]].copy()
    menores = df_idhm.sort_values("idhm", ascending=True).head(N)[["uf", "idhm"]].copy()

# Criar coluna indicando se é Top ou Bottom
maiores["tipo"] = "Maiores"
menores["tipo"] = "Menores"

# Unir tudo em um único DataFrame
ranking_idhm = pd.concat([maiores, menores], axis=0).reset_index(drop=True)

ranking_idhm
# Out:
#              municipio                uf   idhm        regiao     tipo
# 0   SÃO CAETANO DO SUL         São Paulo  0.862       Sudeste  Maiores
# 1   ÁGUAS DE SÃO PEDRO         São Paulo  0.854       Sudeste  Maiores
# 2        FLORIANÓPOLIS    Santa Catarina  0.847           Sul  Maiores
# 3              VITÓRIA    Espírito Santo  0.845       Sudeste  Maiores
# 4   BALNEÁRIO CAMBORIÚ    Santa Catarina  0.845           Sul  Maiores
# 5               SANTOS         São Paulo  0.840       Sudeste  Maiores
# 6              NITERÓI    Rio de Janeiro  0.837       Sudeste  Maiores
# 7              JOAÇABA    Santa Catarina  0.827           Sul  Maiores
# 8             BRASÍLIA  Distrito Federal  0.824  Centro-Oeste  Maiores
# 9             CURITIBA            Paraná  0.823           Sul  Maiores
# 10             MELGAÇO              Pará  0.418         Norte  Menores
# 11     FERNANDO FALCÃO          Maranhão  0.443      Nordeste  Menores
# 12    ATALAIA DO NORTE          Amazonas  0.450         Norte  Menores
# 13      MARAJÁ DO SENA          Maranhão  0.452      Nordeste  Menores
# 14              CHAVES              Pará  0.453         Norte  Menores
# 15            UIRAMUTÃ           Roraima  0.453         Norte  Menores
# 16              JORDÃO              Acre  0.469         Norte  Menores
# 17               BAGRE              Pará  0.471         Norte  Menores
# 18  CACHOEIRA DO PIRIÁ              Pará  0.473         Norte  Menores
# 19           ITAMARATI          Amazonas  0.477         Norte  Menores

# %%
sns.scatterplot(data=df_idhm, x="idhm_renda", y="idhm_educacao", alpha=0.5)

# Linha de tendência com regplot
sns.regplot(
         data=df_idhm,
        x="idhm_renda",
        y="idhm_educacao",
        scatter=False,            # não recria os pontos
        color="red",              # linha de tendência em vermelho
        line_kws={"linewidth": 2} # deixa a linha mais grossa
    )

plt.title("Relação entre IDHM Educação e IDHM Renda")
plt.xlabel("IDHM Renda")
plt.ylabel("IDHM Educação")
plt.tight_layout()
plt.show()

# %%
df_idhm_estado = df_idhm_estado.sort_values(by="idhm_educacao", ascending=False)

plt.figure(figsize=(12,6))

Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm_educacao'],
        width=0.9,
        color = Paleta_Cores
        )

plt.title('UF x IDHM Educação', loc = 'left', fontsize = 18)

plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH', fontsize = 14)
plt.xticks(rotation = 90);

# %%
df_idhm_estado = df_idhm_estado.sort_values(by="idhm_longevidade", ascending=False)

plt.figure(figsize=(12,6))

Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm_longevidade'],
        width=0.9,
        color = Paleta_Cores
        )

plt.title('UF x IDHM Longevidade', loc = 'left', fontsize = 18)

plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH', fontsize = 14)
plt.xticks(rotation = 90);

# %%
df_idhm_estado = df_idhm_estado.sort_values(by="idhm_renda", ascending=False)

plt.figure(figsize=(12,6))

Paleta_Cores = sns.color_palette('mako', len(df_idhm_estado) )
sns.set_style('darkgrid')

plt.bar(df_idhm_estado['uf'],
        df_idhm_estado['idhm_renda'],
        width=0.9,
        color = Paleta_Cores
        )

plt.title('UF x IDHM Renda', loc = 'left', fontsize = 18)

plt.xlabel('UF', fontsize = 14)
plt.ylabel('IDH', fontsize = 14)
plt.xticks(rotation = 90);

# %%
plt.figure()
sns.boxplot(data=df_idhm, x="uf", y="idhm") #municipio
plt.title("Distribuição do IDHM por Estado")
plt.xlabel("Região")
plt.ylabel("IDHM")
plt.tight_layout()
plt.xticks(rotation = 90);
plt.show()

# %%
cols_corr = [c for c in ["idhm_educacao", "idhm_renda", "idhm_longevidade"] if c in df_idhm.columns]
corr = df_idhm[cols_corr].corr()

sns.heatmap(corr, annot=True, fmt=".2f", cmap="rocket", vmin=-1, vmax=1)
plt.title("Matriz de correlação – IDHM e dimensões")
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df_idhm, x="idhm_renda", y="idhm_educacao", alpha=0.5)

# Linha de tendência com regplot
sns.regplot(
         data=df_idhm,
        x="idhm_renda",
        y="idhm_educacao",
        scatter=False,            # não recria os pontos
        color="red",              # linha de tendência em vermelho
        line_kws={"linewidth": 2} # deixa a linha mais grossa
    )

plt.title("Relação entre IDHM Educação e IDHM Renda")
plt.xlabel("IDHM Renda")
plt.ylabel("IDHM Educação")
plt.tight_layout()
plt.show()
